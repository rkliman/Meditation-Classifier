# %% [markdown]
# Link to Excel file of extracted features: https://drive.google.com/drive/u/1/folders/1ZMbW7HxNkBUAlnT-_lXLD4J_r0A778SJ

# %%
# import required packages
import pandas as pd

# %%
# open csv with meditative states
ck_med = pd.read_excel('CK_med.xlsx', index_col=None, header=0)
ck_med['label'] = 'ck_med'
ck_med
# Out:
#       Total Power      Abs LFP      Abs HFP      nLFP      nHFP     LF/HF  \
# 0    10242.236886  2191.200278  7531.913277  0.213938  0.735378  0.290922
# 1    10140.016299  1868.670157  7793.285696  0.184287  0.768567  0.239780
# 2     9930.177172  1660.286319  7725.558626  0.167196  0.777988  0.214908
# 3     9881.551814  1588.519882  7744.244474  0.160756  0.783707  0.205123
# 4     9632.886881  1790.083067  7312.760284  0.185830  0.759145  0.244789
# ..            ...          ...          ...       ...       ...       ...
# 139   1160.095357   223.552939   813.610805  0.192702  0.701331  0.274766
# 140   1420.536153   275.481168  1015.442748  0.193928  0.714831  0.271292
# 141   1393.953672   196.719824  1092.517596  0.141124  0.783755  0.180061
# 142   1267.482134   253.493676   906.193736  0.199998  0.714956  0.279735
# 143   1213.954381   280.524877   833.522461  0.231084  0.686618  0.336553
#
#           RMSSD        SDNN   label
# 0    884.187257   88.067575  ck_med
# 1    865.110274   96.935844  ck_med
# 2    841.936312  102.467241  ck_med
# 3    842.584333  101.717627  ck_med
# 4    826.156703   90.204586  ck_med
# ..          ...         ...     ...
# 139  735.611693  147.849426  ck_med
# 140  766.606858  156.710024  ck_med
# 141  779.975532  148.275939  ck_med
# 142  760.283782  139.385959  ck_med
# 143  769.641956  149.396503  ck_med
#
# [144 rows x 9 columns]

# %%
# open csv with non-meditative states
ck_pre = pd.read_excel('CK_pre.xlsx', index_col=None, header=0)
ck_pre['label'] = 'ck_pre'
ck_pre
# Out:
#       Total Power      Abs LFP      Abs HFP      nLFP      nHFP     LF/HF  \
# 0    11961.755298  3249.551607  8043.922163  0.271662  0.672470  0.403976
# 1     9211.352702  2022.717898  6829.397915  0.219590  0.741411  0.296178
# 2     9283.913716  2378.753676  6678.590063  0.256223  0.719372  0.356176
# 3     9994.154159  2431.402950  7008.622545  0.243283  0.701272  0.346916
# 4     9597.894148  1897.800009  7150.309660  0.197731  0.744987  0.265415
# ..            ...          ...          ...       ...       ...       ...
# 139   1989.099544   662.027791  1154.416138  0.332828  0.580371  0.573474
# 140   2126.568080   702.767596  1205.732791  0.330470  0.566985  0.582855
# 141   1881.590235   567.190494  1057.476732  0.301442  0.562012  0.536362
# 142   1449.142526   275.600103  1092.574487  0.190182  0.753946  0.252248
# 143   1502.545808   357.754224  1044.882642  0.238099  0.695408  0.342387
#
#            RMSSD        SDNN   label
# 0     932.714731   54.825976  ck_pre
# 1     803.437128  120.850089  ck_pre
# 2     793.228617  162.223603  ck_pre
# 3     865.589904   67.238339  ck_pre
# 4     852.451001   70.600140  ck_pre
# ..           ...         ...     ...
# 139  1460.906582   83.783684  ck_pre
# 140  1470.412199   57.335852  ck_pre
# 141  1417.982428   79.030369  ck_pre
# 142  1210.602823  143.285246  ck_pre
# 143  1433.815043  142.395009  ck_pre
#
# [144 rows x 9 columns]

# %%
df = pd.concat([ck_pre,ck_med])
df
# Out:
#       Total Power      Abs LFP      Abs HFP      nLFP      nHFP     LF/HF  \
# 0    11961.755298  3249.551607  8043.922163  0.271662  0.672470  0.403976
# 1     9211.352702  2022.717898  6829.397915  0.219590  0.741411  0.296178
# 2     9283.913716  2378.753676  6678.590063  0.256223  0.719372  0.356176
# 3     9994.154159  2431.402950  7008.622545  0.243283  0.701272  0.346916
# 4     9597.894148  1897.800009  7150.309660  0.197731  0.744987  0.265415
# ..            ...          ...          ...       ...       ...       ...
# 139   1160.095357   223.552939   813.610805  0.192702  0.701331  0.274766
# 140   1420.536153   275.481168  1015.442748  0.193928  0.714831  0.271292
# 141   1393.953672   196.719824  1092.517596  0.141124  0.783755  0.180061
# 142   1267.482134   253.493676   906.193736  0.199998  0.714956  0.279735
# 143   1213.954381   280.524877   833.522461  0.231084  0.686618  0.336553
#
#           RMSSD        SDNN   label
# 0    932.714731   54.825976  ck_pre
# 1    803.437128  120.850089  ck_pre
# 2    793.228617  162.223603  ck_pre
# 3    865.589904   67.238339  ck_pre
# 4    852.451001   70.600140  ck_pre
# ..          ...         ...     ...
# 139  735.611693  147.849426  ck_med
# 140  766.606858  156.710024  ck_med
# 141  779.975532  148.275939  ck_med
# 142  760.283782  139.385959  ck_med
# 143  769.641956  149.396503  ck_med
#
# [288 rows x 9 columns]

# %%
# save df into a csv file
df.to_csv('ck_features.csv',index=False)
